# %%
# !pip install repliclust

import repliclust as rpl
import pickle

archetypes = [ rpl.Archetype.from_verbal_description(descr) for descr in [
    "twelve clusters of different distributions",
    "twelve clusters of different distributions and high class imbalance",
    "seven highly separated clusters in 10D with very different shapes",
    "seven clusters in 10D with very different shapes and significant overlap",
    "four clusters in 100D with 100 samples each",
    "four clusters in 100D with 1000 samples each",
] ]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/ubuntu/repliclust-revision/repliclust
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (3.9.1)
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.26.4)
# Requirement already satisfied: openai in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.16.2)
# Requirement already satisfied: python-dotenv in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.0.1)
# Requirement already satisfied: scikit-learn in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.4.2)
# Requirement already satisfied: scipy in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.14.0)
# Requirement already satisfied: threadpoolctl in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (3.5.0)
# Requirement already satisfied: torch in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (2.4.1)
# Requirement already satisfied: tqdm in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (4.66.4)
# Requirement already satisfied: umap-learn in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (0.5.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (23.2)
# Requirement already satisfied: pillow>=8 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/miniconda/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (2.6.4)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/miniconda/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (4.11.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from scikit-learn->repliclust==0.0.5) (1.4.2)
# Requirement already satisfied: filelock in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.15.4)
# Requirement already satisfied: sympy in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (1.13.0)
# Requirement already satisfied: networkx in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.3)
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.1.4)
# Requirement already satisfied: fsspec in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ubuntu/.local/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->repliclust==0.0.5) (12.5.82)
# Requirement already satisfied: numba>=0.51.2 in /home/ubuntu/.local/lib/python3.11/site-packages (from umap-learn->repliclust==0.0.5) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /home/ubuntu/.local/lib/python3.11/site-packages (from umap-learn->repliclust==0.0.5) (0.5.13)
# Requirement already satisfied: idna>=2.8 in /opt/miniconda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai->repliclust==0.0.5) (3.4)
# Requirement already satisfied: certifi in /opt/miniconda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->repliclust==0.0.5) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->repliclust==0.0.5) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->repliclust==0.0.5) (0.14.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/ubuntu/.local/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn->repliclust==0.0.5) (0.43.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->repliclust==0.0.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/ubuntu/.local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->repliclust==0.0.5) (2.16.3)
# Requirement already satisfied: six>=1.5 in /opt/miniconda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->repliclust==0.0.5) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from jinja2->torch->repliclust==0.0.5) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from sympy->torch->repliclust==0.0.5) (1.3.0)
# Building wheels for collected packages: repliclust
#   Building wheel for repliclust (pyproject.toml) ... done
#   Created wheel for repliclust: filename=repliclust-0.0.5-py3-none-any.whl size=40767 sha256=f6427158cd45f46d366701ac6b38b76762564faa25d1434389d7fcf02df27041
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i9al6oqk/wheels/12/60/99/b2b7f58bf25f0d95d5d3a799ae95badacaff7bfe6ea18fd728
# Successfully built repliclust
# Installing collected packages: repliclust
#   Attempting uninstall: repliclust
#     Found existing installation: repliclust 0.0.5
#     Uninstalling repliclust-0.0.5:
#       Successfully uninstalled repliclust-0.0.5
# Successfully installed repliclust-0.0.5

# %%
# !pip install ../repliclust

import repliclust as rpl
import pickle

with open("./output/archetypes.pkl", "rb") as file:
    archetypes = pickle.load(file)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing /home/ubuntu/repliclust-revision/repliclust
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (3.9.1)
# Requirement already satisfied: numpy in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.26.4)
# Requirement already satisfied: openai in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.16.2)
# Requirement already satisfied: python-dotenv in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.0.1)
# Requirement already satisfied: scikit-learn in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.4.2)
# Requirement already satisfied: scipy in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (1.14.0)
# Requirement already satisfied: threadpoolctl in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (3.5.0)
# Requirement already satisfied: torch in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (2.4.1)
# Requirement already satisfied: tqdm in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (4.66.4)
# Requirement already satisfied: umap-learn in /home/ubuntu/.local/lib/python3.11/site-packages (from repliclust==0.0.5) (0.5.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (23.2)
# Requirement already satisfied: pillow>=8 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda/lib/python3.11/site-packages (from matplotlib->repliclust==0.0.5) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/miniconda/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (2.6.4)
# Requirement already satisfied: sniffio in /home/ubuntu/.local/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/miniconda/lib/python3.11/site-packages (from openai->repliclust==0.0.5) (4.11.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from scikit-learn->repliclust==0.0.5) (1.4.2)
# Requirement already satisfied: filelock in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.15.4)
# Requirement already satisfied: sympy in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (1.13.0)
# Requirement already satisfied: networkx in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.3)
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.1.4)
# Requirement already satisfied: fsspec in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from torch->repliclust==0.0.5) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ubuntu/.local/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->repliclust==0.0.5) (12.5.82)
# Requirement already satisfied: numba>=0.51.2 in /home/ubuntu/.local/lib/python3.11/site-packages (from umap-learn->repliclust==0.0.5) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /home/ubuntu/.local/lib/python3.11/site-packages (from umap-learn->repliclust==0.0.5) (0.5.13)
# Requirement already satisfied: idna>=2.8 in /opt/miniconda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai->repliclust==0.0.5) (3.4)
# Requirement already satisfied: certifi in /opt/miniconda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->repliclust==0.0.5) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /home/ubuntu/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->repliclust==0.0.5) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ubuntu/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->repliclust==0.0.5) (0.14.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/ubuntu/.local/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn->repliclust==0.0.5) (0.43.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->repliclust==0.0.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/ubuntu/.local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->repliclust==0.0.5) (2.16.3)
# Requirement already satisfied: six>=1.5 in /opt/miniconda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->repliclust==0.0.5) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from jinja2->torch->repliclust==0.0.5) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/.local/lib/python3.11/site-packages (from sympy->torch->repliclust==0.0.5) (1.3.0)
# Building wheels for collected packages: repliclust
#   Building wheel for repliclust (pyproject.toml) ... done
#   Created wheel for repliclust: filename=repliclust-0.0.5-py3-none-any.whl size=40797 sha256=0784dafaed739186c95ecf3ba95cf789a586b75ea21f72f21ca91245c4600894
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5x9tz72p/wheels/12/60/99/b2b7f58bf25f0d95d5d3a799ae95badacaff7bfe6ea18fd728
# Successfully built repliclust
# Installing collected packages: repliclust
#   Attempting uninstall: repliclust
#     Found existing installation: repliclust 0.0.5
#     Uninstalling repliclust-0.0.5:
#       Successfully uninstalled repliclust-0.0.5
# Successfully installed repliclust-0.0.5

# %%
from sklearn.cluster import KMeans, SpectralClustering, HDBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score, adjusted_mutual_info_score, adjusted_rand_score
from sklearn.mixture import GaussianMixture

def carry_out_benchmark(X, y, archetype):
    gmm = GaussianMixture(n_components=archetype.n_clusters,
                            max_iter=500, n_init=10,
                            init_params="k-means++")
    kmeans = KMeans(n_clusters=archetype.n_clusters,
                    max_iter=500, n_init=10,
                    init="k-means++")
    hdbscan = HDBSCAN(min_samples=5)
    hac = AgglomerativeClustering(n_clusters=archetype.n_clusters)
    spectral = SpectralClustering(n_clusters=archetype.n_clusters, affinity='nearest_neighbors')

    models = {
        "gmm": gmm,
        "kmeans": kmeans,
        "hdbscan": hdbscan,
        "spectral": spectral,
        "hac": hac
    }

    predictions = {}
    ami_scores = {}
    arand_scores = {}
    f_noise_scores = {}
    
    for model_name in models.keys():
        model = models[model_name]
        y_hat = model.fit_predict(X)

        if model_name == 'hdbscan':
            slxn = (y_hat != -1)
            ami = adjusted_mutual_info_score(y[slxn], y_hat[slxn])
            arand = adjusted_rand_score(y[slxn], y_hat[slxn])
            f_noise = np.mean(y_hat == -1)
        else:
            ami = adjusted_mutual_info_score(y, y_hat)
            arand = adjusted_rand_score(y, y_hat)
            f_noise = 0
        ami_scores[model_name] = ami
        arand_scores[model_name] = arand
        f_noise_scores[model_name] = f_noise

    return { 'archetype': archetype, 'ami_scores': ami_scores, 'arand_scores': arand_scores, 'f_noise_scores': f_noise_scores }

# %%
from tqdm import tqdm
import numpy as np
import pandas as pd

results = []
results_tf = []

for arch in archetypes:
    for _ in tqdm(range(10)):
        # untransformed
        X,y,_ = arch.synthesize(quiet=True)
        record = carry_out_benchmark(X,y,arch)
        results.append(record)

        # transformed
        X_tf = rpl.distort(X)
        record = carry_out_benchmark(X_tf,y,arch)
        results_tf.append(record)
# Out:
# 100%|██████████| 10/10 [00:43<00:00,  4.33s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]/home/ubuntu/.local/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# 100%|██████████| 10/10 [00:42<00:00,  4.23s/it]
#  30%|███       | 3/10 [00:06<00:15,  2.21s/it]/home/ubuntu/.local/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#  40%|████      | 4/10 [00:09<00:14,  2.38s/it]/home/ubuntu/.local/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#  50%|█████     | 5/10 [00:12<00:12,  2.49s/it]/home/ubuntu/.local/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#  60%|██████    | 6/10 [00:14<00:10,  2.50s/it]/home/ubuntu/.local/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
#  90%|█████████ | 9/10 [00:28<00:04,  4.33s/it]/home/ubuntu/.local/lib/python3.11/site-packages/sklearn/manifold/_spectral_embedding.py:301: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# 100%|██████████| 10/10 [00:49<00:00,  4.91s/it]
# 100%|██████████| 10/10 [04:08<00:00, 24.86s/it]
# 100%|██████████| 10/10 [04:14<00:00, 25.42s/it]
# 100%|██████████| 10/10 [27:33<00:00, 165.35s/it]

# %%
import pandas as pd
import numpy as np

with open("./output/results.pkl", "rb") as file:
    results = pickle.load(file)
with open("./output/results_tf.pkl", "rb") as file:
    results_tf = pickle.load(file)

# %%
pd.DataFrame([ record['ami_scores'] | {"archetype": record["archetype"]} for record in results ]).groupby(by="archetype").std()
# pd.DataFrame([ record['ami_scores'] for record in results ]).mean()

pd.DataFrame([ record['ami_scores'] | {"archetype": record["archetype"]} for record in results_tf ]).drop(columns=["archetype"]).std()/np.sqrt(len(archetypes) * 10)
# pd.DataFrame([ record['ami_scores'] for record in results_tf ]).mean()
# Out:
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.192196  0.071925
# four_clusters_100d_100_samples                      0.025535  0.088461
# seven_highly_separated_10d_very_different_shapes    0.029666  0.015038
# seven_very_different_shapes_significant_overlap...  0.060868  0.027187
# twelve_clusters_different_distributions             0.020783  0.026388
# twelve_different_distributions_high_class_imbal...  0.025146  0.023449
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.421637  0.043482
# four_clusters_100d_100_samples                      0.000000  0.072695
# seven_highly_separated_10d_very_different_shapes    0.017563  0.008949
# seven_very_different_shapes_significant_overlap...  0.347019  0.045064
# twelve_clusters_different_distributions             0.141678  0.031506
# twelve_different_distributions_high_class_imbal...  0.171761  0.030163
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.078190
# four_clusters_100d_100_samples                      0.069805
# seven_highly_separated_10d_very_different_shapes    0.006035
# seven_very_different_shapes_significant_overlap...  0.032753
# twelve_clusters_different_distributions             0.023420
# twelve_different_distributions_high_class_imbal...  0.028116

# %%
hdbscan_df = pd.DataFrame([
    {'archetype': record['archetype'], 'ami': record['ami_scores']['hdbscan'], 'ari': record['arand_scores']['hdbscan'], 'noise': record['f_noise_scores']['hdbscan']}
    for record in results
])
hdbscan_tf_df = pd.DataFrame([
    {'archetype': record['archetype'], 'ami': record['ami_scores']['hdbscan'], 'ari': record['arand_scores']['hdbscan'], 'noise': record['f_noise_scores']['hdbscan']}
    for record in results_tf
])

# %%
### HDBSCAN results

print("Mean Scores (Convex Clusters)")
print(hdbscan_df.groupby(by="archetype").mean())

print("\nStandard Deviations (Convex Clusters)")
print(hdbscan_df.groupby(by="archetype").std()/np.sqrt(10))

print("\nAverages (Convex Clusters)")
print(hdbscan_df.drop(columns=['archetype']).mean())

print("\nStandard Deviation for Averages (Convex Clusters)")
print(hdbscan_df.drop(columns=['archetype']).std()/np.sqrt(len(archetypes)*10))

print("\n\nMean Scores (Non-Convex Clusters)")
print(hdbscan_tf_df.groupby(by="archetype").mean())

print("\nStandard Deviations (Non-Convex Clusters)")
print(hdbscan_tf_df.groupby(by="archetype").std()/np.sqrt(10))

print("\nAverages (Non-Convex Clusters)")
print(hdbscan_tf_df.drop(columns=['archetype']).mean())

print("\nStandard Deviation for Averages (Non-Convex Clusters)")
print(hdbscan_tf_df.drop(columns=['archetype']).std()/np.sqrt(len(archetypes)*10))
# Out:
# Mean Scores (Convex Clusters)
#                                                          ami       ari  \
# archetype
# four_clusters_100d_1000_samples                     0.800000  0.800000
# four_clusters_100d_100_samples                      1.000000  1.000000
# seven_highly_separated_10d_very_different_shapes    0.992324  0.983972
# seven_very_different_shapes_significant_overlap...  0.595328  0.616973
# twelve_clusters_different_distributions             0.795948  0.704565
# twelve_different_distributions_high_class_imbal...  0.733352  0.571849
#
#                                                        noise
# archetype
# four_clusters_100d_1000_samples                     0.999400
# four_clusters_100d_100_samples                      1.000000
# seven_highly_separated_10d_very_different_shapes    0.175000
# seven_very_different_shapes_significant_overlap...  0.909286
# twelve_clusters_different_distributions             0.269417
# twelve_different_distributions_high_class_imbal...  0.238000
#
# Standard Deviations (Convex Clusters)
#                                                          ami       ari  \
# archetype
# four_clusters_100d_1000_samples                     0.133333  0.133333
# four_clusters_100d_100_samples                      0.000000  0.000000
# seven_highly_separated_10d_very_different_shapes    0.005554  0.014422
# seven_very_different_shapes_significant_overlap...  0.109737  0.123906
# twelve_clusters_different_distributions             0.044802  0.066196
# twelve_different_distributions_high_class_imbal...  0.054316  0.083452
#
#                                                        noise
# archetype
# four_clusters_100d_1000_samples                     0.000400
# four_clusters_100d_100_samples                      0.000000
# seven_highly_separated_10d_very_different_shapes    0.013533
# seven_very_different_shapes_significant_overlap...  0.019542
# twelve_clusters_different_distributions             0.033119
# twelve_different_distributions_high_class_imbal...  0.041535
#
# Averages (Convex Clusters)
# ami      0.819492
# ari      0.779560
# noise    0.598517
# dtype: float64
#
# Standard Deviation for Averages (Convex Clusters)
# ami      0.035028
# ari      0.040062
# noise    0.049478
# dtype: float64
#
#
# Mean Scores (Non-Convex Clusters)
#                                                          ami       ari  \
# archetype
# four_clusters_100d_1000_samples                     0.031268  0.023266
# four_clusters_100d_100_samples                      0.794005  0.803657
# seven_highly_separated_10d_very_different_shapes    0.746983  0.699698
# seven_very_different_shapes_significant_overlap...  0.163484  0.148797
# twelve_clusters_different_distributions             0.605318  0.400367
# twelve_different_distributions_high_class_imbal...  0.559551  0.355849
#
#                                                        noise
# archetype
# four_clusters_100d_1000_samples                     0.687100
# four_clusters_100d_100_samples                      0.990250
# seven_highly_separated_10d_very_different_shapes    0.416571
# seven_very_different_shapes_significant_overlap...  0.744429
# twelve_clusters_different_distributions             0.353000
# twelve_different_distributions_high_class_imbal...  0.346250
#
# Standard Deviations (Non-Convex Clusters)
#                                                          ami       ari  \
# archetype
# four_clusters_100d_1000_samples                     0.017816  0.016102
# four_clusters_100d_100_samples                      0.137334  0.131390
# seven_highly_separated_10d_very_different_shapes    0.105606  0.117200
# seven_very_different_shapes_significant_overlap...  0.050082  0.065665
# twelve_clusters_different_distributions             0.015722  0.026402
# twelve_different_distributions_high_class_imbal...  0.023817  0.035549
#
#                                                        noise
# archetype
# four_clusters_100d_1000_samples                     0.069649
# four_clusters_100d_100_samples                      0.006937
# seven_highly_separated_10d_very_different_shapes    0.042798
# seven_very_different_shapes_significant_overlap...  0.071812
# twelve_clusters_different_distributions             0.006681
# twelve_different_distributions_high_class_imbal...  0.015671
#
# Averages (Non-Convex Clusters)
# ami      0.483435
# ari      0.405272
# noise    0.589600
# dtype: float64
#
# Standard Deviation for Averages (Non-Convex Clusters)
# ami      0.047427
# ari      0.047460
# noise    0.035604
# dtype: float64

# %%
results_df = pd.DataFrame(results).drop(columns=["hdbscan"])
results_tf_df = pd.DataFrame(results_tf).drop(columns=["hdbscan"])

# %%
### AMI Scores

ami_df = pd.DataFrame([ record['ami_scores'] | {"archetype": record["archetype"]} for record in results ])
ami_tf_df = pd.DataFrame([ record['ami_scores'] | {"archetype": record["archetype"]} for record in results_tf ])

print("AMI Results (Convex)")
print(ami_df.groupby(by="archetype").mean())

print("\nStandard Deviations for AMI Results (Convex)")
print(ami_df.groupby(by="archetype").std()/np.sqrt(10))

print("\nAverages for AMI Results (Convex)")
print(ami_df.drop(columns=["archetype"]).mean())

print("\nStandard Deviations for Averages of AMI Results (Convex)")
print(ami_df.drop(columns=["archetype"]).std()/np.sqrt(len(archetypes)*10))

print("\nAMI Results (Non-Convex)")
print(ami_tf_df.groupby(by="archetype").mean())

print("\nStandard Deviations for AMI Results (Non-Convex)")
print(ami_tf_df.groupby(by="archetype").std()/np.sqrt(10))

print("\nAverages for AMI Results (Non-Convex)")
print(ami_tf_df.drop(columns=["archetype"]).mean())

print("\nStandard Deviations for Averages of AMI Results (Non-Convex)")
print(ami_tf_df.drop(columns=["archetype"]).std()/np.sqrt(len(archetypes)*10))

####### ARI Scores

ari_df = pd.DataFrame([ record['arand_scores'] | {"archetype": record["archetype"]} for record in results ])
ari_tf_df = pd.DataFrame([ record['arand_scores'] | {"archetype": record["archetype"]} for record in results_tf ])

print("ARI Results (Convex)")
print(ari_df.groupby(by="archetype").mean())

print("\nStandard Deviations for ARI Results (Convex)")
print(ari_df.groupby(by="archetype").std()/np.sqrt(10))

print("\nAverages for ARI Results (Convex)")
print(ari_df.drop(columns=["archetype"]).mean())

print("\nStandard Deviations for Averages of ARI Results (Convex)")
print(ari_df.drop(columns=["archetype"]).std()/np.sqrt(len(archetypes)*10))

print("\nARI Results (Non-Convex)")
print(ari_tf_df.groupby(by="archetype").mean())

print("\nStandard Deviations for ARI Results (Non-Convex)")
print(ari_tf_df.groupby(by="archetype").std()/np.sqrt(10))

print("\nAverages for ARI Results (Non-Convex)")
print(ari_tf_df.drop(columns=["archetype"]).mean())

print("\nStandard Deviations for Averages of ARI Results (Non-Convex)")
print(ari_tf_df.drop(columns=["archetype"]).std()/np.sqrt(len(archetypes)*10))
# Out:
# AMI Results (Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.548380  0.664360
# four_clusters_100d_100_samples                      0.063142  0.511513
# seven_highly_separated_10d_very_different_shapes    0.982781  0.975678
# seven_very_different_shapes_significant_overlap...  0.349109  0.451903
# twelve_clusters_different_distributions             0.883547  0.847643
# twelve_different_distributions_high_class_imbal...  0.854256  0.836212
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.800000  0.205358
# four_clusters_100d_100_samples                      1.000000  0.074268
# seven_highly_separated_10d_very_different_shapes    0.992324  0.986217
# seven_very_different_shapes_significant_overlap...  0.595328  0.443404
# twelve_clusters_different_distributions             0.795948  0.859116
# twelve_different_distributions_high_class_imbal...  0.733352  0.852420
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.868393
# four_clusters_100d_100_samples                      0.653726
# seven_highly_separated_10d_very_different_shapes    0.990478
# seven_very_different_shapes_significant_overlap...  0.379917
# twelve_clusters_different_distributions             0.852755
# twelve_different_distributions_high_class_imbal...  0.833547
#
# Standard Deviations for AMI Results (Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.060778  0.022745
# four_clusters_100d_100_samples                      0.008075  0.027974
# seven_highly_separated_10d_very_different_shapes    0.009381  0.004755
# seven_very_different_shapes_significant_overlap...  0.019248  0.008597
# twelve_clusters_different_distributions             0.006572  0.008345
# twelve_different_distributions_high_class_imbal...  0.007952  0.007415
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.133333  0.013750
# four_clusters_100d_100_samples                      0.000000  0.022988
# seven_highly_separated_10d_very_different_shapes    0.005554  0.002830
# seven_very_different_shapes_significant_overlap...  0.109737  0.014251
# twelve_clusters_different_distributions             0.044802  0.009963
# twelve_different_distributions_high_class_imbal...  0.054316  0.009539
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.024726
# four_clusters_100d_100_samples                      0.022074
# seven_highly_separated_10d_very_different_shapes    0.001908
# seven_very_different_shapes_significant_overlap...  0.010357
# twelve_clusters_different_distributions             0.007406
# twelve_different_distributions_high_class_imbal...  0.008891
#
# Averages for AMI Results (Convex)
# gmm         0.613536
# kmeans      0.714551
# hdbscan     0.819492
# spectral    0.570131
# hac         0.763136
# dtype: float64
#
# Standard Deviations for Averages of AMI Results (Convex)
# gmm         0.043931
# kmeans      0.025329
# hdbscan     0.035028
# spectral    0.045764
# hac         0.026397
# dtype: float64
#
# AMI Results (Non-Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.306690  0.145001
# four_clusters_100d_100_samples                      0.076664  0.099953
# seven_highly_separated_10d_very_different_shapes    0.749792  0.605676
# seven_very_different_shapes_significant_overlap...  0.172871  0.149129
# twelve_clusters_different_distributions             0.575876  0.563325
# twelve_different_distributions_high_class_imbal...  0.543747  0.541939
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.031268  0.108686
# four_clusters_100d_100_samples                      0.794005  0.078948
# seven_highly_separated_10d_very_different_shapes    0.746983  0.708901
# seven_very_different_shapes_significant_overlap...  0.163484  0.164638
# twelve_clusters_different_distributions             0.605318  0.565414
# twelve_different_distributions_high_class_imbal...  0.559551  0.547367
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.132027
# four_clusters_100d_100_samples                      0.091626
# seven_highly_separated_10d_very_different_shapes    0.637401
# seven_very_different_shapes_significant_overlap...  0.145131
# twelve_clusters_different_distributions             0.565275
# twelve_different_distributions_high_class_imbal...  0.552534
#
# Standard Deviations for AMI Results (Non-Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.030175  0.013775
# four_clusters_100d_100_samples                      0.010591  0.011744
# seven_highly_separated_10d_very_different_shapes    0.034713  0.027176
# seven_very_different_shapes_significant_overlap...  0.014112  0.008028
# twelve_clusters_different_distributions             0.016749  0.011786
# twelve_different_distributions_high_class_imbal...  0.021373  0.022920
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.017816  0.011887
# four_clusters_100d_100_samples                      0.137334  0.007566
# seven_highly_separated_10d_very_different_shapes    0.105606  0.027045
# seven_very_different_shapes_significant_overlap...  0.050082  0.009735
# twelve_clusters_different_distributions             0.015722  0.014634
# twelve_different_distributions_high_class_imbal...  0.023817  0.024889
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.016358
# four_clusters_100d_100_samples                      0.008316
# seven_highly_separated_10d_very_different_shapes    0.029285
# seven_very_different_shapes_significant_overlap...  0.009703
# twelve_clusters_different_distributions             0.010753
# twelve_different_distributions_high_class_imbal...  0.024051
#
# Averages for AMI Results (Non-Convex)
# gmm         0.404273
# kmeans      0.350837
# hdbscan     0.483435
# spectral    0.362326
# hac         0.353999
# dtype: float64
#
# Standard Deviations for Averages of AMI Results (Non-Convex)
# gmm         0.032205
# kmeans      0.029533
# hdbscan     0.047427
# spectral    0.033448
# hac         0.031171
# dtype: float64
# ARI Results (Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.407845  0.601332
# four_clusters_100d_100_samples                      0.004073  0.404323
# seven_highly_separated_10d_very_different_shapes    0.967119  0.976552
# seven_very_different_shapes_significant_overlap...  0.238304  0.375209
# twelve_clusters_different_distributions             0.854728  0.794552
# twelve_different_distributions_high_class_imbal...  0.800494  0.760433
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.800000  0.185420
# four_clusters_100d_100_samples                      1.000000  0.053749
# seven_highly_separated_10d_very_different_shapes    0.983972  0.987526
# seven_very_different_shapes_significant_overlap...  0.616973  0.385416
# twelve_clusters_different_distributions             0.704565  0.806503
# twelve_different_distributions_high_class_imbal...  0.571849  0.787512
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.874258
# four_clusters_100d_100_samples                      0.554405
# seven_highly_separated_10d_very_different_shapes    0.992276
# seven_very_different_shapes_significant_overlap...  0.290688
# twelve_clusters_different_distributions             0.797795
# twelve_different_distributions_high_class_imbal...  0.756299
#
# Standard Deviations for ARI Results (Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.047827  0.039969
# four_clusters_100d_100_samples                      0.007481  0.036139
# seven_highly_separated_10d_very_different_shapes    0.020254  0.005324
# seven_very_different_shapes_significant_overlap...  0.022599  0.012145
# twelve_clusters_different_distributions             0.010527  0.011876
# twelve_different_distributions_high_class_imbal...  0.018855  0.012217
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.133333  0.011967
# four_clusters_100d_100_samples                      0.000000  0.014174
# seven_highly_separated_10d_very_different_shapes    0.014422  0.002809
# seven_very_different_shapes_significant_overlap...  0.123906  0.015559
# twelve_clusters_different_distributions             0.066196  0.017593
# twelve_different_distributions_high_class_imbal...  0.083452  0.020565
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.031536
# four_clusters_100d_100_samples                      0.027873
# seven_highly_separated_10d_very_different_shapes    0.001564
# seven_very_different_shapes_significant_overlap...  0.015268
# twelve_clusters_different_distributions             0.013718
# twelve_different_distributions_high_class_imbal...  0.017223
#
# Averages for ARI Results (Convex)
# gmm         0.545427
# kmeans      0.652067
# hdbscan     0.779560
# spectral    0.534354
# hac         0.710953
# dtype: float64
#
# Standard Deviations for Averages of ARI Results (Convex)
# gmm         0.046893
# kmeans      0.029509
# hdbscan     0.040062
# spectral    0.045423
# hac         0.030944
# dtype: float64
#
# ARI Results (Non-Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.251605  0.088144
# four_clusters_100d_100_samples                      0.018151  0.062351
# seven_highly_separated_10d_very_different_shapes    0.684027  0.505445
# seven_very_different_shapes_significant_overlap...  0.109269  0.089565
# twelve_clusters_different_distributions             0.368099  0.365064
# twelve_different_distributions_high_class_imbal...  0.340673  0.346944
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.023266  0.064967
# four_clusters_100d_100_samples                      0.803657  0.053139
# seven_highly_separated_10d_very_different_shapes    0.699698  0.628413
# seven_very_different_shapes_significant_overlap...  0.148797  0.088803
# twelve_clusters_different_distributions             0.400367  0.363765
# twelve_different_distributions_high_class_imbal...  0.355849  0.344748
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.071603
# four_clusters_100d_100_samples                      0.050541
# seven_highly_separated_10d_very_different_shapes    0.522788
# seven_very_different_shapes_significant_overlap...  0.080981
# twelve_clusters_different_distributions             0.362300
# twelve_different_distributions_high_class_imbal...  0.359902
#
# Standard Deviations for ARI Results (Non-Convex)
#                                                          gmm    kmeans  \
# archetype
# four_clusters_100d_1000_samples                     0.029292  0.011346
# four_clusters_100d_100_samples                      0.005647  0.010631
# seven_highly_separated_10d_very_different_shapes    0.045249  0.035351
# seven_very_different_shapes_significant_overlap...  0.010800  0.005793
# twelve_clusters_different_distributions             0.021198  0.015003
# twelve_different_distributions_high_class_imbal...  0.021905  0.021449
#
#                                                      hdbscan  spectral  \
# archetype
# four_clusters_100d_1000_samples                     0.016102  0.009634
# four_clusters_100d_100_samples                      0.131390  0.006607
# seven_highly_separated_10d_very_different_shapes    0.117200  0.036185
# seven_very_different_shapes_significant_overlap...  0.065665  0.007327
# twelve_clusters_different_distributions             0.026402  0.014884
# twelve_different_distributions_high_class_imbal...  0.035549  0.025402
#
#                                                          hac
# archetype
# four_clusters_100d_1000_samples                     0.012266
# four_clusters_100d_100_samples                      0.004580
# seven_highly_separated_10d_very_different_shapes    0.039336
# seven_very_different_shapes_significant_overlap...  0.007099
# twelve_clusters_different_distributions             0.011624
# twelve_different_distributions_high_class_imbal...  0.023978
#
# Averages for ARI Results (Non-Convex)
# gmm         0.295304
# kmeans      0.242919
# hdbscan     0.405272
# spectral    0.257306
# hac         0.241352
# dtype: float64
#
# Standard Deviations for Averages of ARI Results (Non-Convex)
# gmm         0.029480
# kmeans      0.023448
# hdbscan     0.047460
# spectral    0.028377
# hac         0.024994
# dtype: float64
